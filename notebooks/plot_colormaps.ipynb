# %%
# %matplotlib inline

# %% [markdown]
# Colormaps
# =========
#
# An example plotting the matplotlib colormaps.

# %%
import sys
sys.path.append('../src')
import numpy as np
import matplotlib.pyplot as plt
from PlotFuncs import *
import cmocean

plt.rc('text', usetex=False)
a = np.outer(np.arange(0, 1, 0.01), np.ones(10))

fig = plt.figure(figsize=(10, 5))
plt.subplots_adjust(top=0.8, bottom=0.05, left=0.01, right=0.99)
maps = [m for m in plt.cm.datad if not m.endswith("_r")]
maps.sort()
l = len(maps) + 1

for i, m in enumerate(maps):
    plt.subplot(1, l, i+1)
    plt.axis("off")
    plt.imshow(a, aspect='auto', cmap=plt.get_cmap(m), origin="lower")
    plt.title(m, rotation=90, fontsize=10, va='bottom')

plt.show()

fig.MySaveFig('cmaps',png=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-1e5ee7376007> in <module>
#      23 plt.show()
#      24
# ---> 25 fig.MySaveFig('cmaps',png=False)
#
# AttributeError: 'Figure' object has no attribute 'MySaveFig'

# %%
import cmocean
m ocmocean.cm.datad
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6b49213c3a98> in <module>
#       1 import cmocean
# ----> 2 cmocean.cm.datad
#
# AttributeError: module 'cmocean.cm' has no attribute 'datad'

# %%
cmaps = OrderedDict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4079cdaa5b83> in <module>
# ----> 1 cmaps = OrderedDict()
#
# NameError: name 'OrderedDict' is not defined

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from colorspacious import cspace_converter
from collections import OrderedDict

cmaps = OrderedDict()

# %%
cmaps
# Out:
# OrderedDict()
